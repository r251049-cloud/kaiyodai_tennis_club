# %% [markdown]
# <a href="https://colab.research.google.com/github/r251049-cloud/kaiyodai_tennis_club/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# !wget 'https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv'
df=pd.read_csv('/content/BostonHousing.csv', header=0, sep=',')
df
# Out:
# --2025-12-27 04:42:08--  https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35735 (35K) [text/plain]
# Saving to: ‘BostonHousing.csv’
#
# BostonHousing.csv   100%[===================>]  34.90K  --.-KB/s    in 0.008s
#
# 2025-12-27 04:42:08 (4.05 MB/s) - ‘BostonHousing.csv’ saved [35735/35735]
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# ...

# %%
x=df.drop(['chas', 'rad', 'b', 'nox', 'medv'], axis=1)
y=df['medv']
x.head()
# Out:
#       crim    zn  indus     rm   age     dis  tax  ptratio  lstat
# 0  0.00632  18.0   2.31  6.575  65.2  4.0900  296     15.3   4.98
# 1  0.02731   0.0   7.07  6.421  78.9  4.9671  242     17.8   9.14
# 2  0.02729   0.0   7.07  7.185  61.1  4.9671  242     17.8   4.03
# 3  0.03237   0.0   2.18  6.998  45.8  6.0622  222     18.7   2.94
# 4  0.06905   0.0   2.18  7.147  54.2  6.0622  222     18.7   5.33

# %%
mean=x.mean(axis=0)
standard=x.std(axis=0)
x=(x-mean)/standard
x.head()
# Out:
#        crim        zn     indus        rm       age       dis       tax  \
# 0 -0.419367  0.284548 -1.286636  0.413263 -0.119895  0.140075 -0.665949
# 1 -0.416927 -0.487240 -0.592794  0.194082  0.366803  0.556609 -0.986353
# 2 -0.416929 -0.487240 -0.592794  1.281446 -0.265549  0.556609 -0.986353
# 3 -0.416338 -0.487240 -1.305586  1.015298 -0.809088  1.076671 -1.105022
# 4 -0.412074 -0.487240 -1.305586  1.227362 -0.510674  1.076671 -1.105022
#
#     ptratio     lstat
# 0 -1.457558 -1.074499
# 1 -0.302794 -0.491953
# 2 -0.302794 -1.207532
# 3  0.112920 -1.360171
# 4  0.112920 -1.025487

# %%
from sklearn.model_selection import train_test_split
np.random.seed(0)
x_train, x_test, y_train, y_test=train_test_split(x ,y, test_size=0.2)
x_train.head()
# Out:
#          crim        zn     indus        rm       age       dis       tax  \
# 220 -0.378471 -0.487240 -0.719610  0.948405  0.707847 -0.443244 -0.600682
# 71  -0.401645 -0.487240 -0.047633 -0.460613 -1.814457  0.708672 -0.612548
# 240 -0.406931  0.799074 -0.904732  0.871549 -0.507122  1.206746 -0.642216
# 6   -0.409837  0.048724 -0.476182 -0.388027 -0.070159  0.838414 -0.576948
# 417  2.595705 -0.487240  1.014995 -1.395688  0.729163 -1.019866  1.529413
#
#       ptratio     lstat
# 220 -0.487557 -0.412132
# 71   0.343873 -0.388326
# 240 -0.857081 -0.178274
# 6   -1.503749 -0.031237
# 417  0.805778  1.958664

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
model=Sequential()
model.add(Dense(1000,activation='relu'))
model.add(Dense(800, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(1))

# %%
from tensorflow.keras.optimizers import Adam
model.compile(Adam(learning_rate=1e-3),loss="mean_squared_error")
history=model.fit(x_train,y_train, batch_size=128,epochs=150, validation_data=(x_test, y_test))
# Out:
# Epoch 1/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - loss: 561.9929 - val_loss: 422.1405
# Epoch 2/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 388.4352 - val_loss: 194.7328
# Epoch 3/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 148.8484 - val_loss: 128.9318
# Epoch 4/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 112.3114 - val_loss: 106.6091
# Epoch 5/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 62.7638 - val_loss: 57.4399
# Epoch 6/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 39.2755 - val_loss: 68.5104
# Epoch 7/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 44.5300 - val_loss: 55.8415
# Epoch 8/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 30.4538 - val_loss: 45.5134
# Epoch 9/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 30.4025 - val_loss: 43.0137
# Epoch 10/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 25.8570 - val_loss: 35.3200
# Epoch 11/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 19.5917 - val_loss: 35.4887
# ...
